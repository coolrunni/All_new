# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('diabetes.csv')

# %%
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
fig, ax = plt.subplots()
ax.boxplot(df['Glucose'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x22ace94e050>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x22ace92e8d0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x22acdc35b10>],
#  'medians': [<matplotlib.lines.Line2D at 0x22ace95ce10>],
#  'fliers': [<matplotlib.lines.Line2D at 0x22ace95fcd0>],
#  'means': []}

# %%
fig, ax = plt.subplots()
ax.hist(df['BMI'])
# Out:
# (array([ 11.,   0.,  15., 156., 268., 224.,  78.,  12.,   3.,   1.]),
#  array([ 0.  ,  6.71, 13.42, 20.13, 26.84, 33.55, 40.26, 46.97, 53.68,
#         60.39, 67.1 ]),
#  <BarContainer object of 10 artists>)

# %%
fig, ax = plt.subplots()
ax.hist(df['SkinThickness'])
# Out:
# (array([231., 107., 165., 175.,  78.,   9.,   2.,   0.,   0.,   1.]),
#  array([ 0. ,  9.9, 19.8, 29.7, 39.6, 49.5, 59.4, 69.3, 79.2, 89.1, 99. ]),
#  <BarContainer object of 10 artists>)

# %%
fig, ax = plt.subplots()
ax.scatter(x=df['Age'], y=df['Glucose'])

# %%
fig, ax = plt.subplots()
ax.scatter(x=df['BMI'], y=df['Insulin'], s=df['Insulin']*0.5, color = "Green")

# %%
# Count the occurrences of each outcome
    
diabetes_cases = df['Outcome'].value_counts()

# Convert to a dictionary for easier handling
diabetes_cases_dict = {
    "Negative": diabetes_cases.get(0, 0),  # 0 for negative cases
    "Positive": diabetes_cases.get(1, 0)   # 1 for positive cases
}
print(diabetes_cases_dict)
# Create a bar chart
plt.bar(diabetes_cases_dict.keys(), diabetes_cases_dict.values(), color=['blue', 'red'])

# Add labels and title
plt.xlabel("Diabetes Outcome")
plt.ylabel("Frequency")
plt.title("Frequency of Diabetes Cases (Positive/Negative)")

# Display the chart
plt.show()
# Out:
# {'Negative': 500, 'Positive': 268}

# %%
sizes = [df['Outcome'].value_counts()[0], df['Outcome'].value_counts()[1]]

# Create the pie chart
fig, ax = plt.subplots()
ax.pie(sizes, labels=['Outcome 0', 'Outcome 1'], autopct='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x22ad4b995d0>,
# ...
#  [Text(-0.5025943242672991, 0.9784676515931925, 'Outcome 0'),
#   Text(0.5025944158780503, -0.9784676045369114, 'Outcome 1')],
#  [Text(-0.27414235869125403, 0.5337096281417413, '65.1%'),
#   Text(0.2741424086607547, -0.5337096024746789, '34.9%')])
